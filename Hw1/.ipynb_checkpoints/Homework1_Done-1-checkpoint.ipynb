# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Question 1

# %%
#Create an array from 1 - 200
numbers = [i for i in range(1, 201)]

#Create a Line Plot of the array
plt.plot(numbers)

# %%
#Create an array x with 10,000 floats in the range [1,10].
x = np.random.uniform(1, 10, 10000)

#Uniform Bin Sizes
plt.hist(x, bins = 10, rwidth = 0.7)
plt.xlabel("Bins")
plt.ylabel("Frequency")
plt.show()

# %%
#Create an array by generating 100 random numbers with normal (aka Gaussian) distribution.
x = np.random.normal(0, 0.1 , size = 100)
#Write the numbers out to a binary file (using numpy). Read the binary file back into an array (using numpy).
np.save("arrayNumbers", x)
y = np.load("arrayNumbers.npy")

#Create a histogram and a bar chart of the data you read back from the binary file.
plt.hist(x, rwidth = 0.7)
plt.ylabel("Frequency")
plt.xlabel("Number")
plt.show()
plt.bar(range(len(x)), x, width = 0.8)
plt.ylabel("Frequency")
plt.xlabel("Number")
plt.show()

# %% [markdown]
# # Question 1C
#
# What information does the histogram shows that the bar chart does not?
#   The Histogram shows how many times a number appeared in our array.
# What information does the bar chart shows that the histogram does not?
#     The Bar Chart Shows each individual value inside our array

# %% [markdown]
# # Question 2

# %%
#Load the NOAA Data
data = np.genfromtxt(fname="NOAA-Temperatures.csv", skip_header=4, delimiter=",", names=True)
x = data["Year"]
y=data["Value"]

#Create a Scatter and Bar Plot of the Data
plt.scatter(x,y)
plt.ylabel("Degrees Celsius +/- From Average")
plt.xlabel("Year")
plt.show()
plt.bar(x,y)
plt.ylabel("Degrees Celsius +/- From Average")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# # Question 2A Part 2 and 3
#
# 2. Describe the trends you see in the data.
#     The first trend I see in the data is that the temperature was decreasing away from the average from 1880 to around 1910 and then it started trending back toward the average from 1910 to about 1940. The next trend I see is a steady rise in temperature away from the average from 1980 to 2020.
#
# 3. I believe the bar chart shows those trends better because the lines make the data easier to read over the dots. The bar chart clearly shows when the temperature was below or above zero while the scatter plot didn't.

# %%
#A different plot that shows the long term trend
plt.plot(x,y)
plt.ylabel("Degrees Celsius +/- From Average")
plt.xlabel("Year")
plt.show()

# %%
data = np.genfromtxt(fname="https://raw.githubusercontent.com/fivethirtyeight/data/master/marriage/both_sexes.csv", delimiter=",", dtype=None, names=True, encoding=None)

poor = data["poor_2534"]
year =data["year"]
rich = data["rich_2534"]

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(year, rich, poor)
ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
ax.grid(True)
plt.legend(['Rich', 'Poor'])
ax.set_title("Poor and Rich marriages based on year", va='bottom')
plt.show()

plt.plot(year, rich)
plt.plot(year, poor)
plt.legend(['Rich', 'Poor'])
plt.ylabel("Percent of Families")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# # Question 2B Part 3
#
# 3. What are some pros and cons of using a Star Plot vs a Line Graph?
#     The star plot is more interesting to look at and you can still see which group is larger but it is a little clustered and hard to read. The line plot on the other hand is very easy to read but is a little more boring. In this case I would prefer the line graph over the star plot.

# %% [markdown]
# # Question 2C
#
# 1. September had the highest number of births
# 2. April had the lowest number of births
# 3. The number of births trends up slightly starting in April and then dips back down by October.

# %%
data = np.genfromtxt(fname="https://raw.githubusercontent.com/fivethirtyeight/data/master/births/US_births_2000-2014_SSA.csv", delimiter=",", dtype=None, names=True, encoding=None)

print(len(data))
month = data["month"]
births = data["births"]
plt.bar(month, births)
plt.ylabel("Number of Births")
plt.xlabel("Month")
plt.show()
# Out:
# 5479

# %% [markdown]
# # Question 2D

# %%
#Data
data = np.genfromtxt(fname="https://raw.githubusercontent.com/fivethirtyeight/data/master/drug-use-by-age/drug-use-by-age.csv", delimiter=",", dtype=None, names=True, encoding=None)

age=data["age"]
heroin=data["heroin_use"]
cocaine = data["cocaine_use"]
alcohol=data["alcohol_use"]
marijuana=data["marijuana_use"]
oxycontin=data["oxycontin_use"]
painReleiver = data["pain_releiver_use"]
stimulant = data["stimulant_use"]
crack = data["crack_use"]
meth = data["meth_use"]
sedatives = data["sedative_use"]


#Good Visualizations.
#These Visualizations are good because they show the ratios between similar drgus. By keeping the drugs
#Seperate we can clearly see the relationships between them. You can also see that drug use seems to peak from the ages of 
#21 to 23 for all drugs. 

plt.bar(age, heroin)
plt.bar(age, meth)
plt.bar(age, crack)
plt.xticks(rotation=45, ha='right')

plt.legend(["Heroin", "Meth", "Crack"])
plt.ylabel("Percent of Users")
plt.xlabel("Age")
plt.show()


plt.bar(age, alcohol)
plt.bar(age, marijuana)
plt.xticks(rotation=45, ha='right')

plt.legend([ "Alcohol", "Marijuana"])
plt.ylabel("Percent of Users")
plt.xlabel("Age")
plt.show()

plt.plot(age, heroin)
plt.plot(age, oxycontin)
plt.plot(age, crack)
plt.plot(age, meth)
plt.plot(age, cocaine)
plt.plot(age, stimulant)
plt.xticks(rotation=45, ha='right')

plt.legend(["Heroin", "Oxycontin","Crack", "Meth", "Cocaine", "Stimulants"])
plt.ylabel("Percent of Users")
plt.xlabel("Age")
plt.show()

# %%
#Bad Visualizations.
#These visualizations are bad because one drug, typically alcohol, overpowers the others and skews the graphs
#so that the usage of other drugs seems so low that its not a problem. 

plt.bar(age, heroin)
plt.bar(age, alcohol)
plt.bar(age, marijuana)
plt.bar(age, oxycontin)
plt.xticks(rotation=45, ha='right')

plt.legend(["Heroin", "Alcohol", "Marijuana", "Oxycontin"])
plt.ylabel("Percent of Users")
plt.xlabel("Age")
plt.show()

plt.plot(age, heroin)
plt.plot(age, alcohol)
plt.plot(age, marijuana)
plt.plot(age, oxycontin)
plt.xticks(rotation=45, ha='right')

plt.legend(["Heroin", "Alcohol", "Marijuana", "Oxycontin"])
plt.ylabel("Percent of Users")
plt.xlabel("Age")
plt.show()

plt.plot(age, heroin)
plt.plot(age, marijuana)
plt.plot(age, oxycontin)
plt.plot(age, crack)
plt.plot(age, meth)
plt.plot(age, cocaine)
plt.plot(age, stimulant)
plt.xticks(rotation=45, ha='right')

plt.legend(["Heroin", "Marijuana", "Oxycontin","Crack", "Meth", "Cocaine", "Stimulants"])
plt.ylabel("Percent of Users")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# # Question 3

# %%
data = np.fromfile('T2.raw\T2.raw', dtype='float32')
data = data.reshape(320, 320, 256)

# show a slice on the X axis
plt.figure()
plt.imshow(data[200,:,:])
plt.gca().invert_yaxis()
plt.savefig('xSlice.png')
plt.show()


# show a slice on the Y axis
plt.figure()
plt.imshow(data[:,120,:])
plt.gca().invert_yaxis()
plt.show()

# show a slice on the Z axis
plt.figure()
plt.imshow(data[:,:,200])
plt.gca().invert_yaxis()
plt.show()

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

am = dict(x=0,y=1,z=2)
axis_widget=widgets.Dropdown(
    options=['x', 'y', 'z'], value='x', description='Axis:')
slice_widget=widgets.IntSlider(min=0, max=42, step=1, value=20)
def update_slice_max(n):
    slice_widget.max=data.shape[am[n]]-1

def show_slice(axis, slice_num):
    update_slice_max(axis)
    slice_num = slice_widget.value
    
    if axis == 'x':
      plt.imshow(data[slice_num,:,:])
    elif axis == 'y':
      plt.imshow(data[:,slice_num,:])
    elif axis == 'z':
      plt.imshow(data[:,:,slice_num])
    
    plt.show()

plt.figure()
data = np.fromfile('T2.raw\T2.raw', dtype='float32')
data = data.reshape(320, 320, 256)
interact(show_slice, slice_num=slice_widget, axis=axis_widget)
# Out:
# interactive(children=(Dropdown(description='Axis:', options=('x', 'y', 'z'), value='x'), IntSlider(value=20, d…
# <function __main__.show_slice(axis, slice_num)>

# %% [markdown]
# 1. What is the topological dimensionality of this dataset?
#     The topological dimenstionality of this dataset is 3D since the data set has 3 independent variables of X,Y,and Z.
# 2. What is the geometrical dimensionality of the visualization in B (the one in the picture above)?
#     The Geometrical dimensionality of part B is 3 since it has 3 variables of X, Y, and Color.
